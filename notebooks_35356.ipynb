# %%
string="python"

# %% [markdown]
# 1. # string.upper()

# %%
string="python"
string.upper()
# Out:
# 'PYTHON'

# %% [markdown]
# # 2. string.lower()

# %%
string="python"
string.lower()
# Out:
# 'python'

# %% [markdown]
# # 3. string.title()

# %%
string.title()
# Out:
# 'Python'

# %% [markdown]
# # 4. string.capatlize()

# %%
string = "python"
string.capitalize()
# Out:
# 'Python'

# %% [markdown]
# # 5. string.strip()

# %%
string = "   python    "
string.strip()
# Out:
# 'python'

# %% [markdown]
# # 6. string.lstrip()

# %%
string = "   python "
string.lstrip()
# Out:
# 'python '

# %% [markdown]
# # 7. string.rstrip()

# %%
string = " python     "
string.rstrip()
# Out:
# ' python'

# %% [markdown]
# # 8. string.find()

# %%
string = "hello world"
print(string.find("world"))
# Out:
# 6

# %% [markdown]
# # 9. string.count()

# %%
string = "Hello world world"
string.count("world")
# Out:
# 2

# %% [markdown]
# # 10. string.replace()

# %%
string = "Welcome to Python programming"
string.replace("Python", "Java")
# Out:
# 'Welcome to Java programming'

# %% [markdown]
# # 11. string.split()

# %%
string = "Python Java C++"
string.split()
# Out:
# ['Python', 'Java', 'C++']

# %% [markdown]
# # 12. join()

# %%
",".join(["C++","Python","PHP","Java"])
# Out:
# 'C++,Python,PHP,Java'

# %% [markdown]
# # 13. string.isalpha()

# %%
string="Hello"
string.isalpha()
# Out:
# True

# %% [markdown]
# # 14.string.isdigit()

# %%
string="9123"
string.isdigit()
# Out:
# True

# %% [markdown]
# # 15. string.isalnum()

# %%
string="Hello123" 
string.isalnum()
# Out:
# True

# %% [markdown]
# # 16. string.startswith()

# %%
string="hello"
string.startswith("h")
# Out:
# True

# %%
string="hello"
string.endswith("o")
# Out:
# True

# %% [markdown]
# # 17. string.len()

# %%
string="python programming"
len("prog")
# Out:
# 4

# %% [markdown]
# # 18. string.swapcase()

# %%
"PYTHON".swapcase()
# Out:
# 'python'

# %% [markdown]
# # 19. center()

# %%
"Hello!!".center(26)
# Out:
# '         Hello!!          '

# %% [markdown]
# # 20.  ljust(width)

# %%
"Hello!!".ljust(15)
# Out:
# 'Hello!!        '

# %% [markdown]
# # 21. rjust(width)

# %%
"Hello!".rjust(10)
# Out:
# '    Hello!'

# %% [markdown]
# # 22. zfill(width)

# %%
"78".zfill(10)
# Out:
# '0000000078'

# %% [markdown]
# # 23. format()

# %%
"Hello {}".format("World")
# Out:
# 'Hello World'

# %% [markdown]
# # 26. rfind()

# %%
"HelloHello".rjust(1)
# Out:
# 'HelloHello'

# %% [markdown]
# # 27. index()

# %%
"Hello!!".index("o")
# Out:
# 4

# %% [markdown]
# # 28. rindex()

# %%
"Hello!!".rindex("o")
# Out:
# 4

# %% [markdown]
# # 29. islower()

# %%
"python".islower()
# Out:
# True

# %% [markdown]
# # 30. isupper()

# %%
"PYTHON".isupper()
# Out:
# True

# %% [markdown]
# # 31. isspace()

# %%
"     ".isspace()
# Out:
# True

# %% [markdown]
# # 32. istitle()

# %%
"Hello World".istitle()
# Out:
# True

# %% [markdown]
# # 33. removeprefix()

# %%
"UNHAPPY".removeprefix("un")
# Out:
# 'UNHAPPY'

# %% [markdown]
# # 34. removesuffix()

# %%
"Playing".removesuffix("ing")
# Out:
# 'Play'

# %% [markdown]
# # 35. translate()

# %%
table = str.maketrans("a","b")
"apple".translate(table)   # bpple
# Out:
# 'bpple'

# %% [markdown]
# # 36. maketrans()

# %%
string.maketrans("A","a")
# Out:
# {65: 97}

# %% [markdown]
# # 37. expandtabs()

# %%
"hi\tworld".expandtabs(14)
# Out:
# 'hi            world'

# %% [markdown]
# # 38. casefold()

# %%
"PYTHON PROGRAMMING".casefold()
# Out:
# 'python programming'

# %% [markdown]
# # 39. rsplit()

# %%
"Java Python PHP c++".rsplit(" ", 2)
# Out:
# ['Java Python', 'PHP', 'c++']

# %% [markdown]
# # 40. splitnes()

# %%
"Java\nPython".splitlines()
# Out:
# ['Java', 'Python']

# %% [markdown]
# # 41. partition()

# %%
"Python programming".partition("  ")
# Out:
# ('Python programming', '', '')

# %% [markdown]
# # 42. rpartition()

# %%
"Welcome to Python programming".rpartition("  ")
# Out:
# ('', '', 'Welcome to Python programming')

# %% [markdown]
# # 43. encode()

# %%
"hello".encode()
# Out:
# b'hello'

# %% [markdown]
# # 44. decode()

# %%
b'hi'.decode()
# Out:
# 'hi'

# %% [markdown]
# # 45. format_map()

# %%
data={"name":"John"}
"hi {name}".format_map(data)
# Out:
# 'hi John'

# %% [markdown]
# # 46. isidentifier()

# %%
"var56".isidentifier()
# Out:
# True

# %% [markdown]
# # 47. isascii()

# %%
"Hi".isascii()
# Out:
# True
